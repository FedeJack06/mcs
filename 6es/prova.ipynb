// %% [markdown]
// # Esempio pyroot

// %%
import ROOT
c=ROOT.TCanvas()
c.Divide(2,1)
c.Draw()
c.cd(1)
f1 = ROOT.TF1("f1","sin(x)/x",-10*ROOT.TMath.Pi(),10*ROOT.TMath.Pi())
f1.Draw()
c.cd(2)
f2 = ROOT.TF1("f2","TMath::Gaus(x,0,1)",-3,3)
f2.Draw()
